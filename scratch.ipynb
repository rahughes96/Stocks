# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
ticker = "PANW"
start_date = "2015-01-01"
end_date = "2024-09-10"

# %%
nvidia_data = yf.download(ticker, start = start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(12,6))
plt.plot(nvidia_data.index, nvidia_data['Close'])
plt.title(f'{ticker} Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()

# %%
nvidia_data.head().to_dict()
# Out:
# {'Open': {Timestamp('2015-01-02 00:00:00'): 40.866668701171875,
#   Timestamp('2015-01-05 00:00:00'): 40.24333190917969,
#   Timestamp('2015-01-06 00:00:00'): 41.33333206176758,
#   Timestamp('2015-01-07 00:00:00'): 41.45333480834961,
#   Timestamp('2015-01-08 00:00:00'): 42.186668395996094},
#  'High': {Timestamp('2015-01-02 00:00:00'): 40.98666763305664,
#   Timestamp('2015-01-05 00:00:00'): 41.39666748046875,
#   Timestamp('2015-01-06 00:00:00'): 41.72999954223633,
#   Timestamp('2015-01-07 00:00:00'): 42.323333740234375,
#   Timestamp('2015-01-08 00:00:00'): 42.540000915527344},
#  'Low': {Timestamp('2015-01-02 00:00:00'): 39.20000076293945,
#   Timestamp('2015-01-05 00:00:00'): 40.060001373291016,
#   Timestamp('2015-01-06 00:00:00'): 39.36333465576172,
#   Timestamp('2015-01-07 00:00:00'): 41.209999084472656,
#   Timestamp('2015-01-08 00:00:00'): 41.93333435058594},
#  'Close': {Timestamp('2015-01-02 00:00:00'): 40.473331451416016,
#   Timestamp('2015-01-05 00:00:00'): 41.24333190917969,
#   Timestamp('2015-01-06 00:00:00'): 40.616668701171875,
#   Timestamp('2015-01-07 00:00:00'): 41.84333419799805,
#   Timestamp('2015-01-08 00:00:00'): 42.4033317565918},
#  'Adj Close': {Timestamp('2015-01-02 00:00:00'): 40.473331451416016,
#   Timestamp('2015-01-05 00:00:00'): 41.24333190917969,
#   Timestamp('2015-01-06 00:00:00'): 40.616668701171875,
#   Timestamp('2015-01-07 00:00:00'): 41.84333419799805,
#   Timestamp('2015-01-08 00:00:00'): 42.4033317565918},
#  'Volume': {Timestamp('2015-01-02 00:00:00'): 4951200,
#   Timestamp('2015-01-05 00:00:00'): 4050600,
#   Timestamp('2015-01-06 00:00:00'): 4053600,
#   Timestamp('2015-01-07 00:00:00'): 3791400,
#   Timestamp('2015-01-08 00:00:00'): 2144400}}
